# %% [markdown]
# # MCP Demo Client
# This notebook demonstrates how to connect to an MCP server using Python.

# %%
from mcp.client.sync_client import SyncMCPClient
client = SyncMCPClient(command=["python", "01-basic-mcp-server/server.py"])
client.start()
client.call_tool('add_numbers', a=5, b=7)
